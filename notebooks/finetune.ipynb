# %%
from xgboost.spark import SparkXGBClassifier
from btc_streamer.ml.preprocessing import BTCDataloader

# %%
btc = BTCDataloader()
btc.setup_spark()
df = btc.load_data('../data/')
train_data, test_data, preproc_spark = btc.preproc_split(df)
# Out:
# > /Users/michieldekoninck/code/Michiel-DK/kafka_streamer/btc_streamer/ml/preprocessing.py(90)preproc_split()
#      89         # Convert feature columns into a single vector column
# ---> 90         feature_columns = [x.name for x in df_final.schema if re.search(r'percent', x.name)]
#      91         assembler = VectorAssembler(inputCols=feature_columns, outputCol='features')
#
# ['percent_change_30m', 'percent_change_1h', 'percent_change_6h', 'percent_change_12h', 'percent_change_24h']

# %%
xgb_classifier = SparkXGBClassifier(
            features_col='features',
            label_col='target',
            num_workers=4,
            device='cpu',
            booster='gbtree',
            eval_metric='logloss',
        )

xgb_classifier.setParams(early_stopping_rounds=5)

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, BinaryClassificationEvaluator
from xgboost.spark import SparkXGBClassifier

# Define the classifier
#xgb_classifier = SparkXGBClassifier()

# Create a parameter grid to search over
paramGrid = ParamGridBuilder() \
    .addGrid(xgb_classifier.max_depth, [3, 5, 7]) \
    .addGrid(xgb_classifier.learning_rate, [0.1, 0.05, 0.01]) \
    .addGrid(xgb_classifier.n_estimators, [100, 200]) \
    .addGrid(xgb_classifier.subsample, [0.8, 1.0]) \
    .build()

# %%
evaluator = BinaryClassificationEvaluator(
    labelCol='target',
    rawPredictionCol='rawPrediction',
    metricName='areaUnderROC'
)

#evaluator = MulticlassClassificationEvaluator()

# %%
crossval = CrossValidator(estimator=xgb_classifier,
                          estimatorParamMaps=paramGrid,
                          evaluator=evaluator,
                          numFolds=3)

# %%
cv_model = crossval.fit(train_data)
# Out:
# 24/09/26 12:02:59 WARN CacheManager: Asked to cache already cached data.
# 24/09/26 12:02:59 WARN CacheManager: Asked to cache already cached data.
# 2024-09-26 12:03:05,257 INFO XGBoost-PySpark: _fit Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.1, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.1, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 2024-09-26 12:03:06,496 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [12:03:07] Task 1 got rank 1
# [12:03:07] Task 2 got rank 2
# [12:03:07] Task 0 got rank 0
# [12:03:07] Task 3 got rank 3
# 2024-09-26 12:03:08,734 INFO XGBoost-PySpark: _fit Finished xgboost training!
# INFO:XGBoost-PySpark:Finished xgboost training!
# 2024-09-26 12:03:14,320 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 2024-09-26 12:03:14,705 INFO XGBoost-PySpark: _fit Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.1, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 1.0, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.1, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 1.0, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 2024-09-26 12:03:14,835 INFO XGBoost-PySpark: _train_booster Training on CPUs
# [12:03:15] Task 1 got rank 1[12:03:15] Task 2 got rank 2            (0 + 4) / 4]
#
# [12:03:15] Task 0 got rank 0
# [12:03:15] Task 3 got rank 3
# 2024-09-26 12:03:17,081 INFO XGBoost-PySpark: _fit Finished xgboost training!
# INFO:XGBoost-PySpark:Finished xgboost training!
# 2024-09-26 12:03:17,243 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 2024-09-26 12:03:17,563 INFO XGBoost-PySpark: _fit Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.1, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 200}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.1, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 200}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 2024-09-26 12:03:17,686 INFO XGBoost-PySpark: _train_booster Training on CPUs
# [12:03:18] Task 1 got rank 1                                        (0 + 4) / 4]
# [12:03:18] Task 2 got rank 2
# [12:03:18] Task 0 got rank 0
# [12:03:18] Task 3 got rank 3
# 2024-09-26 12:03:20,119 INFO XGBoost-PySpark: _fit Finished xgboost training!
# INFO:XGBoost-PySpark:Finished xgboost training!
# 2024-09-26 12:03:20,269 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 2024-09-26 12:03:20,565 INFO XGBoost-PySpark: _fit Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.1, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 1.0, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 200}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.1, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 1.0, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 200}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 2024-09-26 12:03:20,681 INFO XGBoost-PySpark: _train_booster Training on CPUs
# [12:03:21] Task 1 got rank 1                                        (0 + 4) / 4]
# [12:03:21] Task 2 got rank 2
# [12:03:21] Task 0 got rank 0
# [12:03:21] Task 3 got rank 3
# 2024-09-26 12:03:23,074 INFO XGBoost-PySpark: _fit Finished xgboost training!
# INFO:XGBoost-PySpark:Finished xgboost training!
# 2024-09-26 12:03:23,227 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 2024-09-26 12:03:23,536 INFO XGBoost-PySpark: _fit Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.05, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.05, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 2024-09-26 12:03:23,662 INFO XGBoost-PySpark: _train_booster Training on CPUs
# [12:03:24] Task 1 got rank 1                                        (0 + 4) / 4]
# [12:03:24] Task 2 got rank 2
# [12:03:24] Task 0 got rank 0[12:03:24] Task 3 got rank 3
#
# 2024-09-26 12:03:25,906 INFO XGBoost-PySpark: _fit Finished xgboost training!
# INFO:XGBoost-PySpark:Finished xgboost training!
# 2024-09-26 12:03:26,051 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 2024-09-26 12:03:26,337 INFO XGBoost-PySpark: _fit Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.05, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 1.0, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.05, 'max_depth': 3, 'objective': 'binary:logistic', 'subsample': 1.0, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 2024-09-26 12:03:26,461 INFO XGBoost-PySpark: _train_booster Training on CPUs
# [12:03
INFO XGBoost-PySpark: _fit Finished xgboost training!
# INFO:XGBoost-PySpark:Finished xgboost training!
# 24/09/26 12:09:07 WARN DAGScheduler: Broadcasting large task binary with size 1079.2 KiB
# 2024-09-26 12:09:08,047 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 2024-09-26 12:09:08,311 INFO XGBoost-PySpark: _fit Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.01, 'max_depth': 7, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 200}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.01, 'max_depth': 7, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 200}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 2024-09-26 12:09:08,528 INFO XGBoost-PySpark: _train_booster Training on CPUs
# [12:09:09] Task 1 got rank 1                                        (0 + 4) / 4]
# [12:09:09] Task 2 got rank 2
# [12:09:09] Task 0 got rank 0
# [12:09:09] Task 3 got rank 3
# 2024-09-26 12:09:11,804 INFO XGBoost-PySpark: _fit Finished xgboost training!
# INFO:XGBoost-PySpark:Finished xgboost training!
# 2024-09-26 12:09:12,006 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 2024-09-26 12:09:12,368 INFO XGBoost-PySpark: _fit Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.01, 'max_depth': 7, 'objective': 'binary:logistic', 'subsample': 1.0, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 200}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.01, 'max_depth': 7, 'objective': 'binary:logistic', 'subsample': 1.0, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 200}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 2024-09-26 12:09:12,494 INFO XGBoost-PySpark: _train_booster Training on CPUs
# [12:09:13] Task 2 got rank 2                                        (0 + 4) / 4]
# [12:09:13] Task 1 got rank 1
# [12:09:13] Task 0 got rank 0
# [12:09:13] Task 3 got rank 3
# 2024-09-26 12:09:15,691 INFO XGBoost-PySpark: _fit Finished xgboost training!
# INFO:XGBoost-PySpark:Finished xgboost training!
# 2024-09-26 12:09:15,894 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 2024-09-26 12:09:25,543 INFO XGBoost-PySpark: _fit Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.05, 'max_depth': 5, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Running xgboost-2.1.1 on 4 workers with
# 	booster params: {'booster': 'gbtree', 'device': 'cpu', 'eval_metric': 'logloss', 'learning_rate': 0.05, 'max_depth': 5, 'objective': 'binary:logistic', 'subsample': 0.8, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 2024-09-26 12:09:30,152 INFO XGBoost-PySpark: _train_booster Training on CPUs
# [12:09:31] Task 2 got rank 2                                        (0 + 4) / 4]
# [12:09:31] Task 1 got rank 1
# [12:09:31] Task 0 got rank 0
# [12:09:31] Task 3 got rank 3
# 2024-09-26 12:09:32,569 INFO XGBoost-PySpark: _fit Finished xgboost training!
# INFO:XGBoost-PySpark:Finished xgboost training!

# %%
best_model = cv_model.bestModel
predictions = best_model.transform(test_data)
accuracy = evaluator.evaluate(predictions)
print(f"Test Accuracy: {accuracy}")
# Out:
# 2024-09-26 12:12:00,198 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# Test Accuracy: 0.7925291544333053

# %%
best_sklearn = best_model.__dict__['_xgb_sklearn_model']

# %%
best_sklearn.feature_importances_
# Out:
# array([0.85061383, 0.04248043, 0.03901724, 0.03337708, 0.03451145],
#       dtype=float32)

# %%
df.show(10)
# Out:
# +----------+-------------------+-------+--------+--------+--------+--------+-----------+-----------------+
# |      unix|               date| symbol|    open|    high|     low|   close| Volume BTC|       Volume USD|
# +----------+-------------------+-------+--------+--------+--------+--------+-----------+-----------------+
# |1514764740|2017-12-31 23:59:00|BTC/USD|13913.28|13913.28|13867.18| 13880.0| 0.59174759|     8213.4565492|
# |1514764680|2017-12-31 23:58:00|BTC/USD|13913.26|13953.83|13884.69|13953.77| 1.39878396| 19518.3096575292|
# |1514764620|2017-12-31 23:57:00|BTC/USD|13908.73|13913.26|13874.99|13913.26| 0.77501206| 10782.9442939156|
# |1514764560|2017-12-31 23:56:00|BTC/USD| 13827.0|13908.69| 13827.0|13859.58| 0.66645895|   9236.841134241|
# |1514764500|2017-12-31 23:55:00|BTC/USD|13825.05|13825.05|13825.05|13825.05|  0.0655014|     905.56013007|
# |1514764440|2017-12-31 23:54:00|BTC/USD|13884.14|13884.14|13823.88|13854.28|  4.8107019|  66648.811119132|
# |1514764380|2017-12-31 23:53:00|BTC/USD|13854.52| 13898.7|13840.85|13884.15|10.46953115|145360.5409162725|
# |1514764320|2017-12-31 23:52:00|BTC/USD| 13885.0|13898.32|13823.19|13883.13| 7.15371462| 99315.9500523606|
# |1514764260|2017-12-31 23:51:00|BTC/USD|13892.57|13927.21| 13885.0| 13885.0| 0.59592826|     8274.4638901|
# |1514764200|2017-12-31 23:50:00|BTC/USD|13927.34|13927.34|13892.57|13927.28|  0.5654943|7875.797454504001|
# +----------+-------------------+-------+--------+--------+--------+--------+-----------+-----------------+
# only showing top 10 rows

# %%
import matplotlib.pyplot as plt
import wandb

wandb.sklearn.plot_feature_importances(best_sklearn, ['percent_change_30m', 'percent_change_1h', 'percent_change_6h', 'percent_change_12h', 'percent_change_24h']
)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[52], line 4
#       1 import matplotlib.pyplot as plt
#       2 import wandb
# ----> 4 wandb.sklearn.plot_feature_importances(best_sklearn, ['percent_change_30m', 'percent_change_1h', 'percent_change_6h', 'percent_change_12h', 'percent_change_24h']
#       5 )
#
# File ~/.pyenv/versions/3.10.6/envs/kafka_streamer/lib/python3.10/site-packages/wandb/integration/sklearn/plot/classifier.py:249, in feature_importances(model, feature_names, title, max_num_features)
#     247 if not_missing and correct_types and model_fitted:
#     248     feature_importance_chart = calculate.feature_importances(model, feature_names)
# --> 249     wandb.log({"feature_importances": feature_importance_chart})
#
# File ~/.pyenv/versions/3.10.6/envs/kafka_streamer/lib/python3.10/site-packages/wandb/sdk/lib/preinit.py:36, in PreInitCallable.<locals>.preinit_wrapper(*args, **kwargs)
#      35 def preinit_wrapper(*args: Any, **kwargs: Any) -> Any:
# ---> 36     raise wandb.Error(f"You must call wandb.init() before {name}()")
#
# Error: You must call wandb.init() before wandb.log()

# %%
wandb.sklearn.plot_learning_curve(best_sklearn, test_data, y)

# %%
from btc_streamer.ml.preprocessing import BTCDataloader
from pyspark.sql import SparkSession
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from xgboost.spark import SparkXGBClassifier
import re
import logging
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from pyspark.ml.functions import vector_to_array
from pyspark.sql.functions import col

evaluator = BinaryClassificationEvaluator(
    labelCol='target',
    rawPredictionCol='rawPrediction',
    metricName='areaUnderROC'
)
predictions = model.transform(test_data)
roc_auc = evaluator.evaluate(predictions)

preds = model.transform(test_data).select("target", "prediction", 'probability')

preds = preds.withColumn("probability_array", vector_to_array(col("probability")))
preds = preds.withColumn("index_0_probability", col("probability_array")[0])
preds = preds.withColumn("index_1_probability", col("probability_array")[1])

preds_numpy = np.array(preds.select("target", "prediction", 'index_0_probability','index_1_probability').collect())

y_true = preds_numpy[:,0]
y_pred = preds_numpy[:,1]
y_prob = preds_numpy[:,-2:]

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)

scores = {
    'roc_auc': roc_auc,
    'accuracy': acc,
    'precision': precision,
    'recall':recall
}
# Out:
# 2024-09-26 11:59:31,164 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 2024-09-26 11:59:36,121 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs

# %%
scores
# Out:
# {'roc_auc': 0.7909111057560808,
#  'accuracy': 0.7216613628881817,
#  'precision': 0.7314635718891038,
#  'recall': 0.7256156060121522}
